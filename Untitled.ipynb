# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
leagues_by_Revenue = pd.read_csv('./Data/WorldFootballByRevenue.csv')
leagues_by_Revenue
# Out:
#                                                 League                 Sport  \
# 0                       National Football League (NFL)     American football
# 1                          Major League Baseball (MLB)              Baseball
# 2                National Basketball Association (NBA)            Basketball
# 3                                 Premier League (EPL)  Association football
# 4                         National Hockey League (NHL)            Ice hockey
# ..                                                 ...                   ...
# 100     Primera Categoría Serie A (Ecuadorian Serie A)  Association football
# 101                                      Veikkausliiga  Association football
# 102  Mexican Baseball League (Liga Mexicana de Béis...              Baseball
# 103             Russian Volleyball Super League (RVSL)            Volleyball
# 104           Israeli Basketball Premier League (ISBL)            Basketball
#
# ...

# %%
sport_filter = "Association football"
